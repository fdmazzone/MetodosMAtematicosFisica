# %% [markdown]
# <h1> Ejemplo: Resortes Acoplados</h1>
#
# <p align="center">
#     <img  src="osci_aco.png">
# </p>
#
#
# \begin{equation}
# \begin{split}
#              m_1x''(t)&=-k_1x +k_3(y-x) \\
#              m_2y''(t)&=-k_3(y-x)-k_2y
# \end{split}\tag{SL}
# \end{equation}
#
# <h2> Convertimos en una ecuación de orden 4 </h2>

# %%
from sympy import *
init_printing()
var('x,y,t,m1,m2,k1,k2,k3')
x,y=symbols('x,y',cls=Function)
eq1=m1*x(t).diff(t,2)+k1*x(t)-k3*(y(t)-x(t))
eq2=m2*y(t).diff(t,2)+k2*y(t)+k3*(y(t)-x(t))
sust1,=solve(eq2,y(t).diff(t,2))
sust2,=solve(eq1,y(t))
eq3=eq1.diff(t,2).subs({y(t).diff(t,2):sust1, y(t):sust2})
eq3.expand().collect(x(t))
# Out:
#      4                                                                    2
#     d          ⎛k₁⋅k₂   k₁⋅k₃   k₂⋅k₃⎞        ⎛     k₂⋅m₁   k₃⋅m₁     ⎞  d
# m₁⋅───(x(t)) + ⎜───── + ───── + ─────⎟⋅x(t) + ⎜k₁ + ───── + ───── + k₃⎟⋅───(x(
#      4         ⎝  m₂      m₂      m₂ ⎠        ⎝       m₂      m₂      ⎠   2
#    dt                                                                   dt
#
#
#
# t))

# %% [markdown]
# <h2> Convertimos en un sistema de primer orden </h2>
#
# $v=x'$ y $w=y'$
#
# \begin{equation}
# \begin{split}
#             x'&=v\\
#             v'&=-\frac{k_1}{m_1}x +\frac{k_3}{m_1}(y-x) \\
#             y'&=w\\
#             w'&=-\frac{k_3}{m_2}(y-x)-\frac{k_2}{m_2}y
# \end{split}
# \end{equation}
#
# <h1> Sistemas lineales  de ecuaciones diferenciales </h1>
#
# \begin{equation}\left\{
#  \begin{split}
#  \dot{x}_{1}&=a_{11}(t) x_{1}(t)+a_{12}(t) x_{2}(t)+\ldots+a_{1 n}(t) x_{n}(t)+b_{1}(t)\\
#  \vdots &\qquad \vdots\\
#   \dot{x}_{n}&=a_{n1}(t) x_{1}(t)+a_{n2}(t) x_{2}(t)+\ldots+a_{n n}(t) x_{n}(t)+b_{n}(t)\\
#    \end{split} \right. \tag{$SL_1$}
# \end{equation}
#
# Aquí $I\subset\mathbb{R}$ un intervalo, $a_{ij},b_i:I\to\mathbb{R}$ continuas.
#
# Alternativamente poniendo $A=\{a_{ij}\}_{i,j=1}^n$ y $b=(b_1,\ldots,b_n)^t$
#   $$\boxed{
# \dot{x} =A(t) x+b(t).}\tag{$SL_2$}$$
#
# <h3>Sistemas y ecuaciones de orden n</h3>
#
# En general una ecuación lineal de orden $n$
#
# $$
# x^{(n)}(t)=a_{n-1}(t) x^{(n-1)}(t)+a_{n-2}(t) x^{(n-2)}(t)+\cdots+a_{0}(t) x(t)+b(t).
# $$
#
# se transforma en un sistema mediante
#
# $$x_{1}=x, x_{2}=x', \ldots, x_{n}=x^{(n-1)}$$
#
#
# $$
# \left\{
# \begin{split}
# \dot{x}_{1}&=x_{2} \\
# \dot{x}_{2}&=x_{3} \\
# \vdots &  \quad\vdots\\
# \dot{x}_{n-1}&=x_{n} \\
# \dot{x}_{n}&=a_{0}(t) x_{1}+a_{1}(t) x_{2}+\cdots+a_{n-1}(t) x_{n}+b(t)\\
# \end{split}
# \right.
# $$
#
# $$
# A(t)=\begin{pmatrix}
# 0 & 1 & \cdots &\cdots& 0 \\
# 0 & 0 & 1 & \cdots & 0 \\
# a_{0}(t) & a_{1}(t)&a_{2}(t) & \cdots & a_{n-1}(t)
# \end{pmatrix}
# \quad
# b(t)=\begin{pmatrix} 0\\
# \vdots \\
# b(t)
# \end{pmatrix}
# $$
#
#
#
# <h1>La matriz fundamental</h1>
#
#  **Teorema: Existencia y unicidad para Sistemas Lineales** Sea $A:I \rightarrow \mathbb{R}^{n \times n}$, $b: I \rightarrow \mathbb{R}^{n}$ continuas. Entonces para cada $x_{0} \in \mathbb{R}^{n}$ existe una única solucion $x: I \rightarrow \mathbb{R}^{n}$ del PVI.
# $$
# \left\{
# \begin{array}{ll}
#  x^{\prime}(t)&=A(t) x(t)+b(t), \\
#  x\left(t_{0}\right)&=x_{0}
# \end{array}
# \right.
# $$
#
#
#
# **Definicion: Matriz fundamental** Sean $e^1, \ldots e^{n}$ los vectores canónicos de $\mathbb{R}^{n}$, $t_0\in I\subset\mathbb{R}$. Definimos $\Phi^{0}, \ldots, \Phi^{n}:I \rightarrow \mathbb{R}^{n}$ como
# las soluciones de los PVI
# $$
# \left\{
# \begin{split}
# {x}'(t)&=A(t)x(t) \\
# x(t_{0})&=e^{k}
# \end{split}
# \right.
# $$
# La **matriz fundamental** se define como
# $$
# G=\left[\Phi^{1}|\ldots| \Phi^{n}\right]
# $$
#
#
# **Observación.** La matriz fundamental satisface
# $$
# \left\{
# \begin{split}
# {G}'(t)&=A(t) G(t) \\
# G(t_0)&=I_{n\times n}
# \end{split}\right.
# $$
#
#
# **Ejemplo: Osciladar armónico.**
# $$
# {x}''+\omega^{2} x=0.
# $$
# Si $x_{1}=x, x_{2}=\dot{x}$
#
# \begin{equation}
# \left\{
# \begin{split}
# \dot{x}_{1}&=x_{2},\\
# \dot{x}_2 &=-\omega^{2} x_1\\
# \end{split}
# \right.
# \end{equation}
#
# Sabemos que
#
# \begin{align*}
#  x_1(t)&=x_1^0\cos \omega t+x_2^0\operatorname{sen}\omega t,\\
#  x_2(t)&=- x_1^0\omega\operatorname{sen} \omega t+x_2^0\omega\cos\omega t,
#  \end{align*}
#
# Luego
#
# $$
# \left(\begin{array}{l}
# x_{1} \\
# x_{2}
# \end{array}\right)=
# \left(\begin{array}{ll}
# 1 & 0 \\
# 0 & \omega
# \end{array}\right)
# \left(\begin{array}{cc}
# \cos \omega t & \operatorname{sen} \omega t \\
# -\operatorname{sen} \omega t & \cos \omega t
# \end{array}\right) \left(\begin{array}{l}
# x_{1}^{0} \\
# x_{2}^{0}
# \end{array}\right)
# =\left(\begin{array}{ll}
# 1 & 0 \\
# 0 & \omega
# \end{array}\right)   R(-\omega t)\left(\begin{array}{l}
# x_{1}^{0} \\
# x_{0}^{0}
# \end{array}\right)
# $$
#
# Para encontrar la matriz fundamental hay que resolver las condiciones iniciales $x(0)=e^{1}$  y $x(0)=e^{2}$. La condición $x(0)=e^1 \Rightarrow x_{1}^{0}=1$ y $x_{2}^{0}=0$ y la condición
# $x(0)=e^{2} \Rightarrow x_1^0=0$ y $x_0^{2}=1 / \omega$. Luego las columnas de la MF son
#
# $$\Phi_{1}=\left(\begin{array}{ll}1 & 0 \\ 0 & \omega\end{array}\right) R(-\omega t)\left(\begin{array}{l}1 \\ 0\end{array}\right),\quad
# \Phi_{2}=\left(\begin{array}{cc}1 & 0 \\ 0 & \omega\end{array}\right) R(-\omega t)\left(\begin{array}{l}0 \\ 1 / \omega\end{array}\right)
# $$
#
# Entonces
#
# \begin{equation}
# G=\left[\Phi_{1} \mid \Phi_{2}\right]=\left(\begin{array}{ll}1 & 0 \\ 0 & \omega\end{array}\right) R(-\omega t)\left(\begin{array}{ll}1 & 0 \\ 0 & 1/\omega\end{array}\right)=H R(-\omega t) H^{-1}
# \end{equation}
#
#
# **Teorema.** si $G(t)$ es una matriz fundamental  entonces $\Phi(t)=G(t)x_0$, con $x_{0} \in \mathbb{R}^{n}$, es una solución general del problema homogéneo.
# $$x'=A x.$$
#
#
# **Ejercicio.** Demostrar el Teorema.
#
#
# **Corolario.**  El conjunto de solucions de $x'=A x$  es un subespacio $n$-dimensional.
#
#
# La matriz fundamental es invertible. Para probar esto necesitamos
#
#
# **Lema (Derivación de determinantes)**  Supongamos la función matricial $A:I\to\mathbb{R}^{n\times n}$ descompuesta en bloques columna
# $$A=\left[A_{*1}|\ldots| A_{* n}\right].$$
# Supongamos además que $A \in C^{1}\left(I, \mathbb{R}^{n \times n}\right)$. Entonces
# $$\frac{d}{dt}\det( A(t))=\sum_{i=1}^n\det(\left[A_{*1}|\ldots|A'_{*i}|\ldots| A_{* n}\right]).$$
#
# **Demostración.** Usaremos la fórmula de Leibniz del determinante
#
# $$\det(A)=\sum_{\sigma \in S_n}{\epsilon(\sigma)} a_{\sigma(1),1} \cdots a_{\sigma(n),n},
# $$
# donde $S_n$ es el grupo simétrico de orden $n$, esto es el grupo de permutaciones de $n$-elementos y $\epsilon(\sigma)$ es la paridad de la permutación $\sigma$.
#
#
#
# \begin{split}
#  \frac{d}{dt} \det(A)=&\sum_{\sigma \in S_{n}}{\varepsilon(\sigma)} a'_{\sigma(1),1} a_{\sigma(2),2} \cdots a_{\sigma(n),n}\\
#  &+\sum_{\sigma \in S_{n}}{\varepsilon(\sigma)} a_{\sigma(1),1} a'_{\sigma(2),2} \cdots a_{\sigma(n),n}\\
#    &\quad \vdots \\
#  &+\sum_{\sigma \in S_{n}}{\varepsilon(\sigma)} a_{\sigma(1),1} a_{\sigma(2),2} \cdots a'_{\sigma(n),n}\\
#  &+\sum_{i=1}^n\det(\left[A_{*1}|\ldots|A'_{*i}|\ldots| A_{* n}\right])
# \end{split}
# $\square$

# %% [markdown]
# **Observación** También vale que
# \begin{equation}
# \frac{d}{dt}\det( A(t))=\sum_{i=1}^n\det
#     \begin{pmatrix} A_{1*}\\
#                     \vdots \\
#                     A'_{i*} \\
#                     \vdots\\
#                     A_{n*}
#     \end{pmatrix}
# \end{equation}
#
#
#
#
# **Teorema: Fórmula de Liouville.** Si $G$ es la matriz fundamental para $x'=Ax$ entonces
#
# $$\boxed{
# \det(G(t))=e^{\int_{t_{0}}^{t} \operatorname{tr} A(s) ds}
# }$$
#
#
#
#
# **Demostración** Como $G$ es fundamental
# $$
# G'_{i *}=\sum_{j=1}^{n} a_{i j} G_{j *}
# $$
# $$
#  \frac{d}{dt}\det \left(G(t)\right)=
#  \sum_{i=1}^n\det
#     \begin{pmatrix}
#             G_{1*}\\
#             \vdots\\
#             G'_{i*}\\
#             \vdots\\
#             G_{n*}\\
#    \end{pmatrix}
#  =
#   \sum_{i=1}^n\det
#     \begin{pmatrix}
#             G_{1*}\\
#             \vdots\\
#             \sum_{j=1}^na_{ij}G_{j*}\\
#             \vdots\\
#             G_{n*}\\
#    \end{pmatrix}\\
#     =\sum_{i=1}^n\sum_{j=1}^na_{ij}\det
#     \begin{pmatrix}
#             G_{1*}\\
#             \vdots\\
#             G_{j*}\\
#             \vdots\\
#             G_{n*}\\
#    \end{pmatrix}
#       =\sum_{i=1}^n a_{ii}\det
#     \begin{pmatrix}
#             G_{1*}\\
#             \vdots\\
#             G_{i*}\\
#             \vdots\\
#             G_{n*}\\
#    \end{pmatrix}=\operatorname{tr}(A)\det \left(G(t)\right)
# $$
#
#  Integrando sigue el resultado
# $\square$
#
# **Corolario.**  $G(t)$ es no singular.
#
#
# **Ejemplo.** Para el oscilador armónico.
#
# \begin{equation}
#     G(t)=
#     \begin{pmatrix}
#         \cos \omega t & \frac{\operatorname{sen} \omega t}{\omega} \\
#         -\omega \operatorname{sen} \omega t & \cos \omega t
#     \end{pmatrix}.
# \end{equation}
#
# $\operatorname{det}(G(t))=\cos ^{2} \omega t+\operatorname{sen} ^{2} \omega t=1$
#
# $$
# A=\left(\begin{array}{cc}
# 0 & 1 \\
# -\omega^{2} & 0
# \end{array}\right) \Rightarrow \operatorname{tr}(A)=0 \Rightarrow e^{\int_{t_0}^t\operatorname{tr}(A) dt}=1
# $$
#
#
# <h1>Problema no homogéneo</h1>
#
#
# **Teorema.** Supongamos $t_0\in I\subset\mathbb{R}$, $x_0\in\mathbb{R}^n$, $A: I \rightarrow \mathbb{R}^{n\times n}$ y $b: I \rightarrow \mathbb{R}^{n}$ y que $G(t)$ matriz fundamental de $A(t)$ ($G'=AG$, $G(t_0)=I_{n\times n}$), entonces
#
# $$
#     \varphi(t)=G(t)\left[x_{0}+\int_{t_{0}}^{t}(G(s))^{-1} b(s) d s\right]
# $$
# es solución de
#
# \begin{equation}
# \left\{
#  \begin{split}
# x'(t)&=A(t) x(t)+b(t)\\
# x(t_0)&=x_{0}\\
# \end{split}
# \right.
# \end{equation}
#
#
#
# **Demostración**
# $$
# \begin{aligned}
# \dot{\varphi}(t) &=\dot{G}(t)\left[x_{0}+\int_{t_{0}}^{t}(G(s))^{-1} b(s) d{s}\right] +G (t)(G(t))^{-1} b(t) . \\
# =& A G\left[x_{0}+\int_{t o}^{t}(G(s))^{-1} b(s) d s\right]+b(t) \\
# =&A \varphi( t)+b(t)
# \end{aligned}
# $$
#
#
#
# Escribamos la fórmula
#
# $$
# \varphi(t) =G(t) x_{0}+G(t) \int_{t_{0}}^{t}(G(s))^{-1} b(s) d s \\
# =\varphi_{h}(t)+\varphi_{p}(t)
# $$
#
# Notar que $\varphi_h$ resuelve el problema homogéneo y $\varphi_p$ el no-homogéneo.
#
#
# **Ejemplo: (Resorte Forzado)** Se trata de la ecuación
# $$
#  x''(t)=-\omega^2x(t)+F(t).
# $$
#
# Llamando $x_1=x$ y $x_2=x'$,
#
#
# $$
#  \left\{
# \begin{split}
# \dot{x}_{1}&=x_{2} \\
# \dot{x}_{2}&=-{\omega}^2x_{1}(t)+F(t) \\
# \end{split}
# \right.
# $$
# Alternativamente
# $$
# \frac{d}{dt}
#     \begin{pmatrix}
#     x_{1} \\
#     x_{2}
#     \end{pmatrix} =
#     \begin{pmatrix}
#     0 & 1 \\
#     -\omega^{2} & 0
#     \end{pmatrix}
#     \begin{pmatrix}
#     x_{1} \\
#     x_{2}\\
#     \end{pmatrix}+
#     \begin{pmatrix}
#     0 \\
#     F(t)\\
#     \end{pmatrix}
# $$
#
#  $$G(t)=H R(-\omega t) H^{-1},\quad
#  R(-\omega t)=
#  \begin{pmatrix}
# \cos \omega t & \operatorname{sen} \omega t \\
# -\operatorname{sen} \omega t & \cos \omega t
# \end{pmatrix},\quad
# H=
#  \begin{pmatrix}
# 1 & 0 \\
# 0 & \omega
# \end{pmatrix}
# $$
#
# Hallemos $\varphi_{p}$ cuando $t_{0}=0$.
# $$
# \varphi_{p}(t)=G(t) \int_{0}^{t}(G(s))^{-1}
#                 \begin{pmatrix}
#                     0 \\
#                     F(s)\\
#                 \end{pmatrix}
#               d s
#             =\int_{0}^{t} G(t)(G(s))^{-1}                \begin{pmatrix}
#                     0 \\
#                     F(s)\\
#                 \end{pmatrix} d s
# $$
#
# Tenemos
# $$
# G(t)(G(s))^{-1}=H R(-\omega t) H^{-1} H R(\omega s) H^{-1}
# =H R(\omega(s-t)) H^{-1}.
# $$
#
# Ahora
#
#
# \begin{multline*}
# \varphi_{p}(t)=H \int_{0}^{t} R(\omega(s-t)) H^{-1}
#                 \begin{pmatrix}
#                     0 \\
#                     F(s)\\
#                 \end{pmatrix} ds
#     =H \int_{0}^{t} R(\omega(s-t))
#     \begin{pmatrix}
#         0 \\
#         \frac{F(s)}{\omega}\\
#     \end{pmatrix}d s\\
#     =\omega^{-1}H \int_{0}^{t}
#     \begin{pmatrix}
#         -\operatorname{sen}(\omega(s-t))  \\
#         \cos (\omega(s-t))
#     \end{pmatrix}F(s)
#     ds
#     =\omega^{-1} \int_{0}^{t}
#     \begin{pmatrix}
#         -\operatorname{sen}(\omega(s-t))  \\
#         \cos (\omega(s-t))  \\
#     \end{pmatrix}F(s)ds
# \end{multline*}
#
# Luego
#
#
# \begin{split}
# x_{1}(t)&=-\frac{1}{\omega} \int_{0}^{t} \operatorname{sen}(\omega(s-t)) F(s) d s \\
# x_{2}(t)&=\frac{1}{\omega} \int_{0}^{t} \cos (\omega(s-t)) F(s) d s\\
# \end{split}

# %% [markdown]
# <h1>Sistemas lineales homogéneos con coeficientes constantes</h1>
#
# Son sistenas de la forma
# $$
# x'=Ax, \quad A \in \mathbb{R}^{n \times n}\text{ constante}
# $$
#
# La forma de resolver es considerar la sustitución
#
# $$
# y=P^{-1} x
# $$
#
# donde $P$ es no singular.  Entonces
#
# $$
# y'=P^{-1} x'=P^{-1} A x=P^{-1}A Py
# $$
#
# Es una ecuación de la forma
# $$y'=By,\quad \text{con } B \sim A.$$
#
# ¿Que sistemas sabríamos resolver? Si $B$ fuese diagonal
#
# $$B=\operatorname{diag} \left\{ \lambda_{1},\ldots \lambda_{n}\right\}$$
#
# Entonces quedaría un sistema **desacomplado** que podríamos resolver
#
# $$
# \begin{split}
# y'_{1}&=\lambda_{1} y_{1} \\
# &\quad \vdots\\
# y'_{n}&=\lambda_{n} y_{n} \\
# \end{split}
# $$
#
# Las soluciones son:
# $$y_{j}(t)=A_{j} e^{\lambda_{j} t},\quad A_j\in\mathbb{R}$$
#
# La matriz fundamental es
# \begin{equation}
# G(t)=\begin{pmatrix}
# e^{\lambda_{1} t} & \\
# & \ddots \\
# & e^{\lambda_{n} t}\\
# \end{pmatrix}
# \end{equation}
#
# Pero desafortunadamente no toda matriz es diogonalizable.
#
# **Ejercicio.** Demostrar que si $v\in\mathbb{R}^n$ es un autovector asociado al autovalor $\lambda$ de $A$ entonces $x(t)=e^{\lambda t}v$ es solución de $x'=Ax$.
#
#  De manera más general:
#
#  **Ejercicio** Sea $\lambda$ un autovalor y $\{P_1,\ldots,P_k\}$ una cadena de Jordan asociada a $\lambda$
#
# $$AP_1=\lambda P_1,\quad AP_2=\lambda P_2+P_1,\ldots, AP_k=\lambda P_k+P_{k-1}.$$
#
# Demostrar que
# $$
#     \begin{split}
#         \varphi_1(t)&=e^{\lambda t}P_1\\
#         \varphi_2(t)&=e^{\lambda t}\left(P_1 t+ P_2\right)\\
#         \varphi_3(t)&=e^{\lambda t}\left(P_1 \frac{t^2}{2}+ P_2t + P_3\right)\\
#         \vdots      &   \vdots  \\
#         \varphi_k(t)&=e^{\lambda t}\left(P_1 \frac{t^{k-1}}{(k-1)!}+ P_2\frac{t^{k-2}}{(k-2)!}+\cdots + P_{k}\right)\\
#      \end{split}
# $$
# son soluciones linealmente independientes.
#
#
#
#
#
# <h2>Exponencial de matrices</h2>
#
#
# La solución de
#
# $$
# \left\{
# \begin{split}
#     x(t)&=\lambda x(t)  \\
#     x(0)&=x_0 \\
# \end{split}
# \right.
# $$
# con $\lambda,x_0 \in \mathbb{R}$, $x:\mathbb{R}\to\mathbb{R}$, es $x(t)=e^{\lambda t} a$. Razonando por analogia, la de
#
# $$
#  \begin{split}
#   x'&=Ax\\
#   x(0)&=x_0\in\mathbb{R}^n\\
#  \end{split}
# $$
#
# debería ser
# $$x(t)=e^{A t}x_0$$
#
# Para ello deberíamos darle sentido a la exponencial de una matriz.
#
# Recordemos que sobre el espacio de las matrices cuadradas se dice que una norma se llama \emph{norma matricial} si satisface
# $$
#   \|AB\|\leq \|A\|\|B\|.
# $$
# Hay muchas normas matriciales, todas equivalentes. Por ejemplo
# $$
#  \|A\|=\sup\{\|Ax\| \mid  x\in\mathbb{R}^n, \|x\|=1\}.
# $$
#
# Estas normas dotan a $\mathbb{R}^{n\times n}$ de la noción de convergencia. Diremos que las matrices $A_n$ **convergen** a $A$ si
# $$\|A_n-A\|\to 0.$$
#
#
#
# **Definicion (Convergencia de series de matrices)** Sean $A_j\in\mathbb{R}^{n\times n}$, $j=0,1,\ldots$ una sucesión de matrices. Diremos que la serie
# $$
#  \sum_{j=0}^{\infty} A_j
# $$
# converge si la sucesión de sumas parciales
# $$
#  S_m=\sum_{j=0}^{m} A_j
# $$
#  converge en la norma matricial.
#
#
# **Lema** El espacio de las matrices con la norma matricial satisface el criterio de Cauchy, Si $\{A_n\}$ es una sucesión tal que $\|A_n-A_m\|\to 0$ entonces existe una matriz $A$ tal que $A_n\to A$.
#
#
# **Teorema (Exponencial de matrices)** Sea $A\in\mathbb{R}^{n\times n}$. Entonces  la serie matricial
# $$
# \sum_{n=0}^{\infty} \frac{A^n}{n!}=I+A+\frac{A^{2}}{2 !}+\cdots
# $$
# converge. La matriz resultante se denomina exponencial de $A$ y se denota $e^A$.
#
#
# **Demostración.** Veamos que la sucesión de sumas parcales es de Cauchy. Sean $M>N$.
# $$
# \left\|S_{M}-S_{N}\right\|=\left\|\sum_{j=N+1}^{M} \frac{A^{j}}{j!}\right\| \leqslant \sum_{j=N+1}^{M} \frac{\| A \|^j}{j !}
# $$
#  y la última suma puede hacerse tan  chica como queramos pues la serie
# $$
#   e^{\|A\|}=\sum_{n=0}^{\infty}\frac{\|A\|^n}{n!}
# $$
# es convergente $\square$
#
#
#
# **Ejemplo (Matriz diagonal)**  Si
#  $$
#  A=\begin{pmatrix}
# \lambda_{1}&0 & \cdots \\
# \vdots & \ddots& \vdots\\
# 0 &\cdots & \lambda_{n}\\
# \end{pmatrix}
# $$
#
# Entonces
#
#  $$
#  A^j=\begin{pmatrix}
# \lambda^j_{1}&0 & \cdots \\
# \vdots & \ddots& \vdots\\
# 0 &\cdots & \lambda^j_{n}\\
# \end{pmatrix}
# $$
# Luego si $t\in\mathbb{R}$
#
#  $$
#  e^{tA}=\sum_{j=0}^{\infty}\frac{t^j}{j!}\begin{pmatrix}
# \lambda^j_{1}&0 & \cdots \\
# \vdots & \ddots& \vdots\\
# 0 &\cdots & \lambda^j_{n}\\
# \end{pmatrix}=
# \begin{pmatrix}
# \sum_{j=0}^{\infty}\frac{t^j}{j!}\lambda^j_{1}&0 & \cdots \\
# \vdots & \ddots& \vdots\\
# 0 &\cdots & \sum_{j=0}^{\infty}\frac{t^j}{j!}\lambda^j_{n}\\
# \end{pmatrix}
# =
# \begin{pmatrix}
# e^{\lambda_{1}t}&0 & \cdots \\
# \vdots & \ddots& \vdots\\
# 0 &\cdots & e^{\lambda_n t}\\
# \end{pmatrix}
# $$
# Que resulta ser la matriz fundamental del sistema $x'=Ax$.
#
#
#
# **Ejemplo (Oscilador armónico)**
# Calculemos aproximaciones de la exponencial con SymPy para el sistema
# $$
#  \begin{pmatrix}
#   x_1(t)\\
#   x_2(t)
#  \end{pmatrix}'=\begin{pmatrix}
#  0 & 1\\
#  -\omega^2 & 0\\
#   \end{pmatrix}
#  \begin{pmatrix}
#   x_1(t)\\
#   x_2(t)
#  \end{pmatrix}
# $$

# %%
from sympy import *
omega,t=symbols('omega,t')
A=Matrix([[0, 1],[-omega**2,0]])
G=t**0*A**0
for j in range(1,10):
    G=G+t**j*A**j/factorial(j)
G
# Out:
# ⎡    8  8    6  6    4  4    2  2          8  9     6  7    4  5    2  3    ⎤
# ⎢   ω ⋅t    ω ⋅t    ω ⋅t    ω ⋅t          ω ⋅t     ω ⋅t    ω ⋅t    ω ⋅t     ⎥
# ⎢   ───── - ───── + ───── - ───── + 1     ────── - ───── + ───── - ───── + t⎥
# ⎢   40320    720      24      2           362880    5040    120      6      ⎥
# ⎢                                                                           ⎥
# ⎢   10  9    8  7    6  5    4  3          8  8    6  6    4  4    2  2     ⎥
# ⎢  ω  ⋅t    ω ⋅t    ω ⋅t    ω ⋅t     2    ω ⋅t    ω ⋅t    ω ⋅t    ω ⋅t      ⎥
# ⎢- ────── + ───── - ───── + ───── - ω ⋅t  ───── - ───── + ───── - ───── + 1 ⎥
# ⎣  362880    5040    120      6           40320    720      24      2       ⎦

# %% [markdown]
# **Ejemplo (Matrices nilpotentes)** Una matriz $N\in\mathbb{R}^{n\times n}$ se llama **nilpotente** de orden $r\in\mathbb{N}$
# si $ 0 \neq N, O\neq N^{2}, \ldots, O \neq N^{r-1}$ y $ 0=N^{r}$.
# Si $N$ es Nilpotente entonces
# $$
# e^{t N}=I+t N+\frac{t^{2}}{2} N^{2}+\cdots+\frac{t^{r-1}}{(r-1) !} N^{r}
# $$
#
#
# La matriz
# $$
# N=\begin{pmatrix}
# 0 & 1 & \cdots &\cdots & 0 \\
# 0 & 0 & 1 & \cdots & 0 \\
# \vdots &\vdots &\vdots &\ddots &0\\
# 0 & 0 & \cdots & \cdots &  1 \\
# 0 & \cdots & \cdots & \cdots &0\\
# \end{pmatrix},
# $$
#
# es nilpotente. Notar que sobre un vector  opera
#
# $$
# N\begin{pmatrix}
# x_{1} \\
# \vdots\\
# \vdots\\
# x_{n}
# \end{pmatrix}=
# \begin{pmatrix}
# x_{2} \\
# x_{3} \\
# \vdots\\
# x_n\\
# 0\\
# \end{pmatrix}
# $$
#
# Luego
#
# $$
# \begin{split}
#     N^2&=\begin{pmatrix}
# 0 & 0&  1 & \cdots &\cdots & 0 \\
# 0 & 0 & 0 & 1 & \cdots & 0 \\
# \vdots &\vdots &\vdots &\vdots &\ddots &0\\
# 0 & 0 & 0 & \cdots & \cdots &  1 \\
# 0 & \cdots & \cdots& \cdots & \cdots &0\\
# 0 & \cdots & \cdots & \cdots & \cdots &0\\
# \end{pmatrix},\\
# \quad \vdots &\qquad\qquad\qquad  \vdots \\
#     N^{n-1}&=\begin{pmatrix}
# 0 & 0&  0 & \cdots &\cdots & 1 \\
# 0 & 0 & 0 & 0 & \cdots & 0 \\
# \vdots &\vdots &\vdots &\vdots &\ddots &0\\
# 0 & 0 & 0 & \cdots & \cdots &  0 \\
# 0 & \cdots & \cdots& \cdots & \cdots &0\\
# 0 & \cdots & \cdots & \cdots & \cdots &0\\
# \end{pmatrix},\\
# N^n&=\boldsymbol{0}
# \end{split}
# $$
#
# Luego
#
# $$
# \begin{split}
# e^{N t}&=I+t N+\frac{t^{2}}{2!} N^{2}+\cdots+\frac{t^{n-1}}{(n-1)!} N^{n-1}\\
#         &=\begin{pmatrix}
#         1 & \cdots & 0\\
#         0 & \ddots & 0 \\
#         0&\cdots  & 1
#         \end{pmatrix}+
#         \begin{pmatrix}
#         0 & t & \cdots & 0 \\
#         \vdots & \vdots &\ddots & \vdots \\
#         0 & \cdots & \cdots & t \\
#         0 & \cdots & \cdots & 0 \\
#         \end{pmatrix}+
#         \begin{pmatrix}
#         0 &\cdots &  \frac{t^{n-1}}{(n-1) !} \\
#         0 & \cdots &  0 \\
#         0 & \cdots &  0 \\
#         0 & \cdots &  0 \\
#         \end{pmatrix}.\\
#         &=
#         \begin{pmatrix}
#             1 & t & \frac{t^2}{2!} & \cdots & \frac{t^{n-1}}{(n-1) !}  \\
#             \vdots & \vdots &\ddots&\ddots & \vdots \\
#               0 & \cdots &  \cdots &\cdots & \frac{t^2}{2!} \\
#             0 & \cdots &  \cdots &\cdots & t \\
#             0 & \cdots  & \cdots& \cdots & 1 \\
#         \end{pmatrix}
# \end{split}
# $$
#
#
#
#
#
# **Ejemplo** Calculemos $e^{R}$ donde
# $$
# R=\begin{pmatrix}
#      \mu & \nu \\ -\nu & \mu\\
#     \end{pmatrix}
# $$
#
# Definimos
# $$
#  \mathcal{M}=\left\{
#         \begin{pmatrix}
#      \mu & \nu \\ -\nu & \mu\\
#     \end{pmatrix}
#     \mid
#     \mu, \nu \in \mathbb{R}
#     \right\}.
# $$
#
#
# **Ejercicio** $M$ es  cuerpo. (b) La función:
#
# \begin{array}{ll}
#  f:  \mathbb{C}&\to &\mathcal{M}\\
#     \mu+i\nu & \mapsto
#     &\begin{pmatrix}
#             \mu & \nu \\ -\nu & \mu\\
#     \end{pmatrix}
#  \end{array}
# es continua y un isomorfismo de cuerpos.
#
#
#
# $$
# R=\begin{pmatrix}
# \mu & \nu \\
# -\nu & \mu
# \end{pmatrix}=f(\mu+\nu i)=f(z)
# $$
#
#
#
#
#  \begin{multline}
#     e^{R}   =\lim _{n \rightarrow \infty}\left(I+R+\cdots+\frac{R^{n}}{n!}\right)
#            =\lim _{n \rightarrow \infty}\left(f(1)+f(z)+\frac{f^{2}(z)}{2!}+\cdots+\frac{f^n(z)}{n!}\right)\\
#            =\lim _{n \rightarrow \infty} f\left(1+z+\frac{z^{2}}{2}+\cdots+\frac{z^{n}}{n !}\right)
#            =f\left(\lim _{n \rightarrow \infty}\left(1+z+\cdots+\frac{z^{n}}{n!}\right)\right)\\
#            =f\left(e^{z}\right)=f\left(e^{\mu}(\cos \nu+i \operatorname{sen} \nu)\right)
#      =
#         \begin{pmatrix}
#             e^{\mu} \cos \nu & e^{\mu } \operatorname{sen} \nu \\
#             -e^{\mu} \operatorname{sen}\nu & e^{\mu} \cos \nu
#         \end{pmatrix}
#          =e^{\mu}
#         \begin{pmatrix}
#             \cos \nu & \operatorname{sen} \nu \\
#             -\operatorname{sen} \nu & \cos \nu
#         \end{pmatrix}
#  \end{multline}
#
# \end{ejemplo}
#
#
# **Teorema[Propiedades de la exponencial]**
#
#
# 1. $e^{\boldsymbol{0}}=I$,
#
# 2. $e^{P^{-1}AP}=P^{-1} e^{A}P$. En particular  $A \sim B \Rightarrow e^{A}\sim e^{B}$,
#
# 3. Si $A$  conmuta con $B$ $(A B=B A)$ entonces
#  $$e^{A+B} =e^{A} e^{B} ,$$
#
# 4. $e^A$ es no singular y $\left(e^A\right)^{-1}=e^{-A}$.
#
#
#
#
# **Demostración**
#
# Demostremos 2. Observar que
# $$
#  \left(P^{-1}AP\right)^n=P^{-1}APP^{-1}AP\cdots P^{-1}AP=P^{-1}A^nP
# $$
# Luego
# $$e^{P^{-1} A P}= \sum_{n=0}^{\infty}\frac{ \left(P^{-1} A P\right)^n}{n!}
# = \sum_{n=0}^{\infty}\frac{P^{-1} A^n P}{n!}
# =P^{-1} \left(\sum_{n=0}^{\infty}\frac{ A^n}{n!}  \right)P=P^{-1}e^AP.
# $$
#
#
# Demostremos 3. Usando la formula del binomio de Newton
# $$(A+B)^{n}=\sum_{j=0}^{n} \binom{n}{j} A^{j} B^{n-j}$$
# Luego
# $$
# e^{A+B}=\sum_{n=0}^{\infty}\frac{1}{n!} \sum_{j=0}^{n}\binom{n}{j}
# A^{j} B^{n-j}
# $$
# Por otro lado
# $$
# \begin{aligned}
# e^{A}  e^{B}&=\left(I+A+\frac{A^{2}}{2 !}+\frac{A^{3}}{3 !}+\cdots\right)\left(I+B+\frac{B^{2}}{2}+\frac{B^{3}}{3}+\cdots\right) \\
# &=I+A+B+\frac{A^{2}}{2}+A B+\frac{B^{2}}{2}+\frac{A^{3}}{3 !}+\frac{A^{2}}{2 !} B+A \frac{B^{2}}{2 !}+\frac{B^{3}}{3}+\cdots\\
# &=\sum_{n=0}^{\infty} \frac{1}{n!}\sum_{j=0}^{n}\binom{n}{j} A^j B^{n-j}=e^{A+B}
# \end{aligned}
# $$
#  $\square$
#
#
#
# **Teorema [Exponencial y matriz fundamental]** Si $A\in\mathbb{R}^{n\times n}$ entonces
#  $$
#   \frac{d}{d t} e^{A t}=A e^{A t} =e^{A t} A \\
#  $$
# Luego si $G(t)=e^{A t}$, como $G(0)=I$,  $G(t)$ es la matriz fundamental para
# el sistema $x'=Ax$ en $t_0=0$.
#
#
# **Demostración**
# \begin{multline*}
# \frac{d}{d t} e^{t A}=\lim _{h \rightarrow 0} \frac{e^{(t+h) A}-e^{t A}}{h}=\lim _{h \rightarrow 0} \frac{e^{h A} e^{t A}-e^{t A}}{h}
# =\left[\lim _{n \rightarrow 0}\left(\frac{e^{h A}-I}{h}\right)\right] e^{t A}\\
# =\lim _{h \rightarrow 0} \frac{\left(h A+\frac{h^2}{2} A^{2}+\cdots\right)}{h} e^{t A}
# =A \lim _{h \rightarrow 0}\left(I+h(A+\cdots)) e^{t A}=A e^{t A}\right.
# \end{multline*}
# $\square$.
#
# <h2>Exponenciales y formas de Jordan</h2>
#
# Podemos usar las formas de Jordan Para calcular de manera explícita la exponencial de una matriz.
#
# Un bloque elemental  de Jordan asociado a un autovalor real $\lambda\in\mathbb{R}$ es una matriz  de la siguiente forma
# $$
# \begin{split}
#  J&=
#    \begin{pmatrix}
#     \lambda & 1        & \cdots& \cdots  &0\\
#     0         &\lambda  &  1      &\cdots &0 \\
#     \vdots    & \vdots   &\ddots  &\ddots&\vdots \\
#      \vdots    & \vdots  & \vdots   &\lambda  &1\\
#       0    & 0   & \cdots& \cdots &\lambda\\
#    \end{pmatrix}\\
#    &=
#       \begin{pmatrix}
#     \lambda & 0        & \cdots& \cdots  &0\\
#     0         &\lambda  &  0      &\cdots &0 \\
#     \vdots    & \vdots   &\ddots  &\ddots&\vdots \\
#      \vdots    & \vdots  & \vdots   &\lambda  &0\\
#       0    & 0   & \cdots& \cdots &\lambda\\
#    \end{pmatrix}
#   +
#       \begin{pmatrix}
#     0 & 1        & \cdots& \cdots  &0\\
#     0         &0  &  1      &\cdots &0 \\
#     \vdots    & \vdots   &\ddots  &\ddots&\vdots \\
#      \vdots    & \vdots  & \vdots   &0  &1\\
#       0    & 0   & \cdots& \cdots &0\\
#    \end{pmatrix}\\
#    &=\lambda I+N.
# \end{split}
# $$
# Como $t\lambda I$ y $tN$ conmutan
# $$e^{tJ}=e^{t(\lambda I+N)}=e^{t\lambda I}e^{tN}.$$
# Cada uno de los factores $e^{t\lambda I}$ y $e^{tN}$ los hemos calculado.
#
#
# Si $J$ esta compuesta de varios bloques elementales de Jordan
#
# $$
#  J=
#    \begin{pmatrix}
#     J_1 & 0        & \cdots& \cdots  &0\\
#     0         &J_2  &  0      &\cdots &0 \\
#     \vdots    & \vdots   &\ddots  &\ddots&\vdots \\
#      \vdots    & \vdots  & \vdots   &J_{k-1}  &0\\
#       0    & 0   & \cdots& \cdots &J_k\\
#    \end{pmatrix}
# $$
#
# Entonces
# $$
#  e^{tJ}=
#    \begin{pmatrix}
#     e^{tJ_1} & 0        & \cdots& \cdots  &0\\
#     0         &e^{tJ_2}  &  0      &\cdots &0 \\
#     \vdots    & \vdots   &\ddots  &\ddots&\vdots \\
#      \vdots    & \vdots  & \vdots   &e^{tJ_{k-1}}  &0\\
#       0    & 0   & \cdots& \cdots &e^{tJ_k}\\
#    \end{pmatrix}
# $$
#
# Utilizando estos recursos podemos calcular la exponencial de cualquier matriz de la que conozcamos su forma de Jordan.
#
# <h2> Caso autovalores complejos </h2>
# Cuando hay autovalores complejos los resultados de los calculos anteriores nos llevan a soluciones  que toman valores complejos. Sin embargo, suele ser el caso que busquemos soluciones que tomen valores reales.
#
# Es relativamente sencillo obtener soluciones reales a partir de soluciones complejas, veamos un ejemplo particular que va a ilustrar como proceder en general.
#
# Supongamos $\lambda\in\mathbb{C}\notin\mathbb{R}$ un autovalor complejo y no real y $P\in\mathbb{C}^n$ su correspondiente autovector. Por un ejercicio de más arriba sabemos que $\varphi(t)=e^{\lambda t}P$ es solución con valores en $\mathbb{C}$.  Escribamos
# $$
# \lambda=\mu+i\nu,\quad P=Q+iR, \quad \mu,\nu\in\mathbb{R}\hbox{ y } Q,R\in\mathbb{R}^n.
# $$
#
# Como la matriz $A$ es real $\bar{\lambda}=\mu-i\nu$ es autovector y $\bar{P}=Q-iR$ es un autovector correspondiente y tambien se tiene que $\bar{\varphi}e^{\bar{\lambda}t}\bar{P}$ es solución. Luego  las siguientes  combinaciones lineales son solución
#
# $$
# \psi_1(t)=\frac12\varphi(t)+ \frac12\bar{\varphi}(t)=\boxed{e^{\mu t}\left(\cos\nu t Q-\operatorname{sen}\nu t R   \right)}\\
# \psi_2(t)=-\frac{i}{2}\varphi(t)+ \frac{i}{2}\bar{\varphi}(t)=\boxed{e^{\mu t}\left(\cos\nu t R+\operatorname{sen}\nu t P   \right)}
# $$
# es solución. Se puede demostrar que son linealmente independientes en $\mathbb{R}$.
#
# **Conclusión** Cuando tenemos un autovalor complejo, lo juntamos con su conjugado y formamos el doble de soluciones. Del par de autovalores conjugados solo consideramos uno.
#
# Cuando hay autovalores deficientes se procede de manera similar.

# %% [markdown]
# **Deber** Leer para el final clasificación de los retratos de fases de los sistemas planos
#
#
#
# <h2> El problema no-homogéneo para sistemas con coeficientes constantes</h2>
#
# **Corolario.** Sea $A\in \mathbb{R}^{n\times n}$ constante, $t_o\in\mathbb{R}$ y $x_0\in\mathbb{R}^n$. La solución del PVI
# $$
#  \left\{
#     \begin{array}{ll}
#         x^{\prime}&=A x+b(t)\\
#         x(t_0)&=x_0\\
#     \end{array}
#   \right.
# $$
# viene dada por la expresión
#
# $$x(t)=e^{A(t-t_0)} x_0+\int_{t_0}^{t} e^{A(t-s)} b(s) d s.$$
#
#
# **Demostración**  Se verifica que la matriz  $G(t)=e^{A(t-t_0)}$ resuelve $G'(t)=AG(t)$ y $G(t_0)=I$. Luego es una matriz fundamental del sistema $x'=Ax$ en $t_0$. Usando la fórmula para resolver sistemas no homogéneos deuducimos
# $$
#  x(t)=e^{A(t-t_0)}\left[x_0 +\int_{t_0}^t e^{A(t_0-s)}b(s)ds\right]=e^{A(t-t_0)}x_0 +\int_{t_0}^t e^{A(t-s)}b(s)ds
# $$
#
# $\square$
#
#
#
#
#
#
#
#
# **Ejemplo** Sea $A\in\mathbb{R}^{3\times 3}$
#
# $$A=
# \begin{pmatrix}- \frac{11}{18} & \frac{34}{45} & - \frac{22}{45}\\- \frac{62}{45} & \frac{53}{90} & - \frac{28}{45}\\- \frac{1}{45} & \frac{23}{45} & - \frac{7}{90}\\
# \end{pmatrix}
# $$
#
# Usemos la función jordan_form de SymPy para averiguar la forma de Jordan compleja asociada a $A$.

# %%
A=Rational(1,90)*Matrix([[-55, 68, -44],\
    [-124, 53, -56],\
    [-2, 46, -7]])
P1,J1=A.jordan_form()
P1, J1
# Out:
# ⎛⎡-1/3  1 - ⅈ  1 + ⅈ⎤  ⎡1/10      0          0    ⎤⎞
# ⎜⎢                  ⎥  ⎢                          ⎥⎟
# ⎜⎢1/3   -2⋅ⅈ    2⋅ⅈ ⎥, ⎢ 0    -1/10 - ⅈ      0    ⎥⎟
# ⎜⎢                  ⎥  ⎢                          ⎥⎟
# ⎝⎣ 1      1      1  ⎦  ⎣ 0        0      -1/10 + ⅈ⎦⎠

# %% [markdown]
# La matriz es diagonalizable.  Del autovalor real $\frac{1}{10}$ tenemos el autovector
#
# $$
# P_1=\begin{pmatrix}
#                                     -\frac{1}{3}\\
#                                     \frac{1}{3}  \\
#                                     1\\
#                                   \end{pmatrix}
# $$
#
#
#
#
# Del par de autovalores conjugados $-\frac{1}{10}\pm i$ tomamos el  $-\frac{1}{10} + i$ y su correspondiente autovector $P_2$. Entonces
#
# $$
# Q_2=\begin{pmatrix}
#         1\\
#         0  \\
#         1\\
#    \end{pmatrix}
# ,\quad
# R_2=\begin{pmatrix}
#         1\\
#         2  \\
#         0\\
#    \end{pmatrix}
# $$
#
# Usando las fórmulas de arriba, tres soluciones linealmente independientes son:
#
# $$\varphi_1(t):=e^{\frac{1}{10}t}\begin{pmatrix}
#                                     -\frac{1}{3}\\
#                                     \frac{1}{3}  \\
#                                     1\\
#                                   \end{pmatrix}
#   ,\\
#   \varphi_2(t):=e^{-\frac{1}{10}t}\cos\nu t \begin{pmatrix}
#         1\\
#         0  \\
#         1\\
#    \end{pmatrix}
#    -e^{-\frac{1}{10}t}\operatorname{sen}\nu t \begin{pmatrix}
#         1\\
#         2  \\
#         0\\
#    \end{pmatrix},\\
#      \varphi_3(t):=e^{-\frac{1}{10}t}\cos\nu t \begin{pmatrix}
#         1\\
#         2  \\
#         0\\
#    \end{pmatrix}
#    +e^{-\frac{1}{10}t}\operatorname{sen}\nu t  \begin{pmatrix}
#         1\\
#         0  \\
#         1\\
#    \end{pmatrix}
#    $$

# %% [markdown]
# Este resultado nos indica que las soluciones se comportaran como un foco estable en el subespacio generado por los vectores $Q_2,R_2$
# y como $e^tP_1$ sobre el subespacio generado por $P_1$.
#
#  El subespacio $S_1$ generado por $P_1$ y el $S_2$ generado por $\{Q_2,R_2\}$ son invariantes. Una solución que inicialmente está en $S_1$ permanece allí y tiende a $+\infty$. En cambio si inicialmente está en $S_2$ permanecerá en el plano $S_2$ describiendo una trayectoria de foco estable.  Es de esperar que una solución cualquiera tienda a $+\infty$ a medida que se va enrollando alrededor del eje generado por $P_1$.
#
#
# Grafiquemos una solución con condición inicial en $S_2$

# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.integrate import odeint
A=1/90*np.array([[-55, 68, -44],\
    [-124, 53, -56],\
    [-2, 46, -7]])
def EcuaLin1(X,t):
    return A.dot(X)

t=np.arange(0,20,.01)

ax = plt.figure().add_subplot(projection='3d')

V1=np.array([-1/3,  1/3, 1])
V2=np.array([1,0,1])
V3=np.array([1,2,0])

sol=odeint(EcuaLin1, V1,t)
ax.plot(sol[:,0],sol[:,1],sol[:,2])

sol=odeint(EcuaLin1, V2+V3,t)
ax.plot(sol[:,0],sol[:,1],sol[:,2])

# %% [markdown]
# <h2> Osciladores acoplados </h2>
#
# \begin{equation}
# \begin{split}
#             x'&=v\\
#             v'&=-\frac{k_1}{m_1}x +\frac{k_3}{m_1}(y-x) \\
#             y'&=w\\
#             w'&=-\frac{k_3}{m_2}(y-x)-\frac{k_2}{m_2}y
# \end{split}
# \end{equation}
#
# Lamemos $x_1=x$, $x_2=v$, $x_3=y$ y $x_4=w$
#
# $$
# \begin{pmatrix}
# \dot{x}_1\\
# \dot{x}_2\\
# \dot{x}_3\\
# \dot{x}_4\\
# \end{pmatrix}
# $$

# %%
k1,k2,k3,m1,m2=symbols('k1,k2,k3,m1,m2',positive=True)
A=Matrix([[0,1,0,0],\
          [-(k1/m1+k3/m1), 0, k3/m1, 0],\
          [0,0,0,1],[k3/m2, 0, -(k3/m2+k2/m2),0]   ])
A=A.subs({k1:1,k2:1,k3:1,m1:1,m2:1})
P,D=A.jordan_form()
P,D
# Out:
# ⎛⎡       -√3⋅ⅈ    √3⋅ⅈ ⎤                      ⎞
# ⎜⎢ⅈ  -ⅈ  ──────   ──── ⎥                      ⎟
# ⎜⎢         3       3   ⎥  ⎡-ⅈ  0    0     0  ⎤⎟
# ⎜⎢                     ⎥  ⎢                  ⎥⎟
# ⎜⎢1  1     -1      -1  ⎥  ⎢0   ⅈ    0     0  ⎥⎟
# ⎜⎢                     ⎥, ⎢                  ⎥⎟
# ⎜⎢        √3⋅ⅈ   -√3⋅ⅈ ⎥  ⎢0   0  -√3⋅ⅈ   0  ⎥⎟
# ⎜⎢ⅈ  -ⅈ   ────   ──────⎥  ⎢                  ⎥⎟
# ⎜⎢         3       3   ⎥  ⎣0   0    0    √3⋅ⅈ⎦⎟
# ⎜⎢                     ⎥                      ⎟
# ⎝⎣1  1     1       1   ⎦                      ⎠

# %% [markdown]
# Podemos considerar los autovalores $i$ y $\sqrt{3}i$. Tenemos $\mu_1=0$, $\nu_1=1$, $\mu_2=0$, $\nu_2=\sqrt{3}$. Además
# $$
# Q_1=\begin{pmatrix}
#         0\\
#         1  \\
#         0\\
#         1\\
#    \end{pmatrix},\quad
# R_1=\begin{pmatrix}
#         -1\\
#         0 \\
#         -1\\
#         0\\
#    \end{pmatrix},\quad
# Q_2=\begin{pmatrix}
#         0\\
#         -1  \\
#         0\\
#         1\\
#    \end{pmatrix},\quad
# R_2=\begin{pmatrix}
#         \frac{\sqrt{3}}{3}\\
#         0 \\
#         -\frac{\sqrt{3}}{3}\\
#         0\\
#    \end{pmatrix},
# $$

# %% [markdown]
# Obtenemos que la solución general se escribe:
#
# $$
# \varphi(t)=c_1\begin{pmatrix}
#         \operatorname{sen} t\\
#         \cos  t \\
#         \operatorname{sen} t\\
#         \cos  t\\
#    \end{pmatrix}
#    +
# c_2\begin{pmatrix}
#         -\cos  t \\
#         \operatorname{sen} t\\
#          -\cos  t\\
#          \operatorname{sen} t\\
#      \end{pmatrix}+
# c_3\begin{pmatrix}
#         -\operatorname{sen}\frac{\sqrt{3}}{3}t\\
#         -\cos \frac{\sqrt{3}}{3} t \\
#         \operatorname{sen}\frac{\sqrt{3}}{3} t\\
#         \cos \frac{\sqrt{3}}{3} t\\
#    \end{pmatrix}
#    +
# c_4\begin{pmatrix}
#         \cos \frac{\sqrt{3}}{3} t \\
#         -\operatorname{sen}\frac{\sqrt{3}}{3} t\\
#          -\cos \frac{\sqrt{3}}{3} t\\
#          \operatorname{sen}\frac{\sqrt{3}}{3} t\\
#      \end{pmatrix}
# $$

# %% [markdown]
# Si tomamos $c_3=c_4=0$ la solución  resultará $2\pi$ periódica. Observar que en este caso $x=y$ los desplazamientos son iguales.
#
# Si tomamos $c_1=c_2=0$ la solución  resultará $2\pi/\sqrt{3}$ periódica. Observar que en este caso $x=-y$ los desplazamientos son opuestos.
#
# La superposición de dos funciones oscilatorias con frecuencias cuyo cociente es un número irracional no resulta periódica (para una demostración ver apuntes Ecuaciones Diferenciales 1913). Entonces $c_3=c_4=0$, $c_1=c_2=0$ son las únicas elecciones que nos dan una solución periódica. Se llaman **modos normales de vibración**.
